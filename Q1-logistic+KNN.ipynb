# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Chaudhary Computer\\Desktop\\Data mining and Machine learning\\assignment\\wifi_localization.txt', delimiter='\t')

# %%
df.columns = ['WiFi1', 'WiFi2', 'WiFi3', 'WiFi4', 'WiFi5', 'WiFi6', 'WiFi7', 'Room']

# %%
df.head
# Out:
# <bound method NDFrame.head of       WiFi1  WiFi2  WiFi3  WiFi4  WiFi5  WiFi6  WiFi7  Room
# 0       -64    -56    -61    -66    -71    -82    -81     1
# 1       -68    -57    -61    -65    -71    -85    -85     1
# 2       -63    -60    -60    -67    -76    -85    -84     1
# 3       -61    -60    -68    -62    -77    -90    -80     1
# 4       -63    -65    -60    -63    -77    -81    -87     1
# ...     ...    ...    ...    ...    ...    ...    ...   ...
# 1995    -59    -59    -48    -66    -50    -86    -94     4
# 1996    -59    -56    -50    -62    -47    -87    -90     4
# 1997    -62    -59    -46    -65    -45    -87    -88     4
# 1998    -62    -58    -52    -61    -41    -90    -85     4
# 1999    -59    -50    -45    -60    -45    -88    -87     4
#
# [2000 rows x 8 columns]>

# %%
df.iloc[:,:]
# Out:
#       WiFi1  WiFi2  WiFi3  WiFi4  WiFi5  WiFi6  WiFi7  Room
# 0       -64    -56    -61    -66    -71    -82    -81     1
# 1       -68    -57    -61    -65    -71    -85    -85     1
# 2       -63    -60    -60    -67    -76    -85    -84     1
# 3       -61    -60    -68    -62    -77    -90    -80     1
# 4       -63    -65    -60    -63    -77    -81    -87     1
# ...     ...    ...    ...    ...    ...    ...    ...   ...
# 1995    -59    -59    -48    -66    -50    -86    -94     4
# 1996    -59    -56    -50    -62    -47    -87    -90     4
# 1997    -62    -59    -46    -65    -45    -87    -88     4
# 1998    -62    -58    -52    -61    -41    -90    -85     4
# 1999    -59    -50    -45    -60    -45    -88    -87     4
#
# [2000 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   WiFi1   2000 non-null   int64
#  1   WiFi2   2000 non-null   int64
#  2   WiFi3   2000 non-null   int64
#  3   WiFi4   2000 non-null   int64
#  4   WiFi5   2000 non-null   int64
#  5   WiFi6   2000 non-null   int64
#  6   WiFi7   2000 non-null   int64
#  7   Room    2000 non-null   int64
# dtypes: int64(8)
# memory usage: 125.1 KB

# %%
df.shape
# Out:
# (2000, 8)

# %%
df.describe()
# Out:
#              WiFi1        WiFi2        WiFi3        WiFi4        WiFi5  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    -52.330500   -55.623500   -54.964000   -53.566500   -62.640500
# std      11.321677     3.417688     5.316186    11.471982     9.105093
# min     -74.000000   -74.000000   -73.000000   -77.000000   -89.000000
# 25%     -61.000000   -58.000000   -58.000000   -63.000000   -69.000000
# 50%     -55.000000   -56.000000   -55.000000   -56.000000   -64.000000
# 75%     -46.000000   -53.000000   -51.000000   -46.000000   -56.000000
# max     -10.000000   -45.000000   -40.000000   -11.000000   -36.000000
#
#              WiFi6        WiFi7         Room
# count  2000.000000  2000.000000  2000.000000
# mean    -80.985000   -81.726500     2.500000
# std       6.516672     6.519812     1.118314
# min     -97.000000   -98.000000     1.000000
# 25%     -86.000000   -87.000000     1.750000
# 50%     -82.000000   -83.000000     2.500000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for WiFi signal distributions
df.iloc[:, :-1].hist(figsize=(12, 8))
plt.suptitle('Histograms of WiFi Signal Strengths')
plt.tight_layout()
plt.show()

# %%
df.isnull().sum()
# Out:
# WiFi1    0
# WiFi2    0
# WiFi3    0
# WiFi4    0
# WiFi5    0
# WiFi6    0
# WiFi7    0
# Room     0
# dtype: int64

# %%
# Box plot to identify outliers
plt.figure(figsize=(12, 8))
sns.boxplot(data=df.iloc[:, :-1])
plt.title('Box Plots for WiFi Signal Strengths')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Set up the matplotlib figure
plt.figure(figsize=(14, 10))

# t WiFi signal columns (assuming they are named 'Wifi1', 'Wifi2', ..., 'Wifi7')
wifi_columns = ['WiFi1', 'WiFi2', 'WiFi3', 'WiFi4', 'WiFi5', 'WiFi6', 'WiFi7']  # Explicit column names

# Create a color palette for multiple lines
palette = sns.color_palette("Set2", n_colors=len(wifi_columns))  # Define color palette

# Create line plots for each WiFi signal
for i, wifi_col in enumerate(wifi_columns, 1):
    plt.subplot(3, 3, i)  # Create a grid for up to 9 subplots
    sns.lineplot(data=df, x='Room', y=wifi_col, marker='o', palette=palette)  # Use 'df' and correct column references
    plt.title(f'{wifi_col} Signal Strength by Room')
    plt.xlabel('Room (Class)')
    plt.ylabel('Signal Strength (dBm)')
    plt.xticks(ticks=[1, 2, 3, 4], labels=['Class 1', 'Class 2', 'Class 3', 'Class 4'])

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# Index(['WiFi1', 'WiFi2', 'WiFi3', 'WiFi4', 'WiFi5', 'WiFi6', 'WiFi7', 'Room'], dtype='object')
# C:\Users\Chaudhary Computer\AppData\Local\Temp\ipykernel_2484\995700441.py:19: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df, x='Room', y=wifi_col, marker='o', palette=palette)  # Use 'df' and correct column references
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
from sklearn.model_selection import train_test_split
#split data into X=features and y=target
X=df.iloc[:,:-1]
y=df['Room']

# %%
#split into training and testing sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

#apply standardization

sc=StandardScaler()
X_train_s=sc.fit_transform(X_train)
X_test_s=sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
# Initialize KNN classifier with specified parameters
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(X_test)
print(y_pred)
# Out:
# [1 3 3 2 4 3 4 3 4 1 3 4 1 1 2 4 1 4 4 3 4 3 2 4 3 3 1 3 2 4 3 3 4 4 3 1 3
#  1 1 2 1 3 3 1 4 2 1 1 4 3 4 3 1 2 1 2 1 4 3 4 2 4 3 3 1 2 2 3 2 1 1 2 4 4
#  1 4 1 1 4 4 2 1 1 3 4 1 4 1 1 1 1 3 1 3 4 4 4 1 4 1 4 3 2 4 1 2 3 4 3 2 1
#  4 2 3 4 2 4 1 2 1 2 1 3 1 4 3 2 3 2 3 2 1 1 1 4 1 2 3 2 1 4 2 3 2 1 2 1 1
#  4 4 1 4 2 4 1 2 1 2 2 3 4 4 3 3 4 2 4 4 2 3 2 3 1 1 2 4 2 1 4 1 3 4 4 1 4
#  3 3 2 1 4 3 2 1 2 2 3 4 1 3 4 3 2 1 2 3 4 4 4 1 3 1 2 1 3 1 1 3 1 3 2 1 2
#  2 2 2 4 4 4 1 4 2 1 4 4 4 3 3 4 2 3 2 2 3 2 2 3 1 1 2 1 4 4 4 4 4 1 4 4 3
#  1 3 1 2 3 2 3 4 4 4 4 3 2 2 2 2 3 2 1 4 3 3 3 4 1 3 2 2 3 3 1 1 4 3 1 2 2
#  2 2 3 2 3 3 3 2 3 4 1 1 4 4 1 3 1 3 4 2 1 1 3 4 3 3 1 1 4 4 2 3 3 1 3 4 4
#  3 2 1 2 1 3 1 4 3 2 3 2 4 4 1 4 2 1 4 3 2 2 3 3 4 1 2 3 1 3 3 1 3 1 1 3 3
#  1 3 1 2 3 4 1 1 3 1 2 1 1 3 2 3 3 2 3 4 1 1 4 3 3 3 1 4 4 2 2 1 4 1 2 2 1
#  1 3 3 1 4 2 3 2 1 3 3 3 2 4 1 3 1 4 2 2 2 4 2 4 1 1 3 3 2 3 2 2 2 3 4 3 2
# ...

# %%
print(y_test)
# Out:
# 405     1
# 1190    3
# 1132    3
# 731     2
# 1754    4
#        ..
# 841     2
# 108     1
# 665     2
# 1214    3
# 2       1
# Name: Room, Length: 600, dtype: int64

# %%
from sklearn import metrics
acc=metrics.accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.9816666666666667

# %%
from sklearn import metrics
cm=metrics.confusion_matrix(y_test,y_pred)
print('Confusion Matrix:')
print(cm,'\n\n')
print('---------')

result=metrics.classification_report(y_test,y_pred)
print('classification Report:/n')
print(result)
# Out:
# Confusion Matrix:
# [[157   0   0   0]
#  [  0 143   8   0]
#  [  1   0 151   1]
#  [  1   0   0 138]]
#
#
# ---------
# classification Report:/n
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       157
#            2       1.00      0.95      0.97       151
#            3       0.95      0.99      0.97       153
#            4       0.99      0.99      0.99       139
#
#     accuracy                           0.98       600
#    macro avg       0.98      0.98      0.98       600
# weighted avg       0.98      0.98      0.98       600

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualization 1: Confusion Matrix
# Assuming 'cm' is your confusion matrix
plt.figure(figsize=(8, 6))  # Set figure size for the confusion matrix
ax = sns.heatmap(cm, cmap='flare', annot=True, fmt='d')
plt.xlabel("Predicted Class", fontsize=12)
plt.ylabel("True Class", fontsize=12)
plt.title("Confusion Matrix", fontsize=14)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
# Initialize logistic regression classifier
log_reg = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)

# Train the model
log_reg.fit(X_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %%
y_logpred=knn.predict(X_test)
print(y_logpred)
# Out:
# [1 3 3 2 4 3 4 3 4 1 3 4 1 1 2 4 1 4 4 3 4 3 2 4 3 3 1 3 2 4 3 3 4 4 3 1 3
#  1 1 2 1 3 3 1 4 2 1 1 4 3 4 3 1 2 1 2 1 4 3 4 2 4 3 3 1 2 2 3 2 1 1 2 4 4
#  1 4 1 1 4 4 2 1 1 3 4 1 4 1 1 1 1 3 1 3 4 4 4 1 4 1 4 3 2 4 1 2 3 4 3 2 1
#  4 2 3 4 2 4 1 2 1 2 1 3 1 4 3 2 3 2 3 2 1 1 1 4 1 2 3 2 1 4 2 3 2 1 2 1 1
#  4 4 1 4 2 4 1 2 1 2 2 3 4 4 3 3 4 2 4 4 2 3 2 3 1 1 2 4 2 1 4 1 3 4 4 1 4
#  3 3 2 1 4 3 2 1 2 2 3 4 1 3 4 3 2 1 2 3 4 4 4 1 3 1 2 1 3 1 1 3 1 3 2 1 2
#  2 2 2 4 4 4 1 4 2 1 4 4 4 3 3 4 2 3 2 2 3 2 2 3 1 1 2 1 4 4 4 4 4 1 4 4 3
#  1 3 1 2 3 2 3 4 4 4 4 3 2 2 2 2 3 2 1 4 3 3 3 4 1 3 2 2 3 3 1 1 4 3 1 2 2
#  2 2 3 2 3 3 3 2 3 4 1 1 4 4 1 3 1 3 4 2 1 1 3 4 3 3 1 1 4 4 2 3 3 1 3 4 4
#  3 2 1 2 1 3 1 4 3 2 3 2 4 4 1 4 2 1 4 3 2 2 3 3 4 1 2 3 1 3 3 1 3 1 1 3 3
#  1 3 1 2 3 4 1 1 3 1 2 1 1 3 2 3 3 2 3 4 1 1 4 3 3 3 1 4 4 2 2 1 4 1 2 2 1
#  1 3 3 1 4 2 3 2 1 3 3 3 2 4 1 3 1 4 2 2 2 4 2 4 1 1 3 3 2 3 2 2 2 3 4 3 2
# ...

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_logpred)
print(f"Accuracy: {accuracy:.2f}")

# Generate a classification report
print("Classification Report:")
print(classification_report(y_test, y_logpred))
# Out:
# Accuracy: 0.98
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       157
#            2       1.00      0.95      0.97       151
#            3       0.95      0.99      0.97       153
#            4       0.99      0.99      0.99       139
#
#     accuracy                           0.98       600
#    macro avg       0.98      0.98      0.98       600
# weighted avg       0.98      0.98      0.98       600

# %%
from sklearn import metrics
cm=metrics.confusion_matrix(y_test,y_logpred)
print('Confusion Matrix:')
print(cm,'\n\n')
print('---------')

result=metrics.classification_report(y_test,y_logpred)
print('classification Report:/n')
print(result)
# Out:
# Confusion Matrix:
# [[157   0   0   0]
#  [  0 143   8   0]
#  [  1   0 151   1]
#  [  1   0   0 138]]
#
#
# ---------
# classification Report:/n
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       157
#            2       1.00      0.95      0.97       151
#            3       0.95      0.99      0.97       153
#            4       0.99      0.99      0.99       139
#
#     accuracy                           0.98       600
#    macro avg       0.98      0.98      0.98       600
# weighted avg       0.98      0.98      0.98       600
